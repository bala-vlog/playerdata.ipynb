# %%
# import library

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
from matplotlib.pyplot import figure


# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8) #adjust the configuration of the plot we will create

#read the data

df = pd.read_csv(r'C:\Users\DES\Desktop\variables.csv')

# %%
# let's look at the data

df.head()
# Out:
#    Unnamed: 0             Name  Apps  Mins    Mins/Gm  Height  Weight  Age  \
# 0           0  Josip Mijatović    12   809  67.416667     173      68   20
# 1           1    Duje Ninčević    15  1161  77.400000     172      69   25
# 2           2  Marin Karabatić    15  1350  90.000000     170      62   22
# 3           3     Vicko Ševelj    20  1738  86.900000     192      86   22
# 4           4    Fran Vujnović    15  1384  92.266667     190      77   19
#
#    Av Rat  Distance                           Based  CA  Saves  Dist/Mins  \
# 0    7.14     102.6          Croatia (3. HNL Zapad)  84      0   0.126823
# 1    6.84     150.3            Croatia (3. HNL Jug)  79      0   0.129457
# 2    6.90     172.8            Croatia (3. HNL Jug)  87      0   0.128000
# 3    7.15     101.9  Bosnia & Herzegovina (Liga 12)  95      0   0.058631
# 4    7.23      22.2          Croatia (3. HNL Istok)  83      0   0.016040
#
#   Transfer Value     Value
# 0      €3K - €9K    6000.0
# ...

# %%
# lets see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# Unnamed: 0 - 0.0%
# Name - 0.0%
# Apps - 0.0%
# Mins - 0.0%
# Mins/Gm - 0.0%
# Height - 0.0%
# Weight - 0.0%
# Age - 0.0%
# Av Rat - 0.0%
# Distance - 0.0%
# Based - 0.0%
# CA - 0.0%
# Saves - 0.0%
# Dist/Mins - 0.0%
# Transfer Value - 0.0%
# Value - 0.0%

# %%
# data type for our columns

df.dtypes
# Out:
# Unnamed: 0          int64
# Name               object
# Apps                int64
# Mins                int64
# Mins/Gm           float64
# Height              int64
# Weight              int64
# Age                 int64
# Av Rat            float64
# Distance          float64
# Based              object
# CA                  int64
# Saves               int64
# Dist/Mins         float64
# Transfer Value     object
# Value             float64
# dtype: object

# %%
# change data type pf columns

df['Apps'] = df['Apps'].astype('int64')
df['Weight'] = df['Weight'].astype('int64')
df.head()
# Out:
#    Unnamed: 0             Name  Apps  Mins    Mins/Gm  Height  Weight  Age  \
# 0           0  Josip Mijatović    12   809  67.416667     173      68   20
# 1           1    Duje Ninčević    15  1161  77.400000     172      69   25
# 2           2  Marin Karabatić    15  1350  90.000000     170      62   22
# 3           3     Vicko Ševelj    20  1738  86.900000     192      86   22
# 4           4    Fran Vujnović    15  1384  92.266667     190      77   19
#
#    Av Rat  Distance                           Based  CA  Saves  Dist/Mins  \
# 0    7.14     102.6          Croatia (3. HNL Zapad)  84      0   0.126823
# 1    6.84     150.3            Croatia (3. HNL Jug)  79      0   0.129457
# 2    6.90     172.8            Croatia (3. HNL Jug)  87      0   0.128000
# 3    7.15     101.9  Bosnia & Herzegovina (Liga 12)  95      0   0.058631
# 4    7.23      22.2          Croatia (3. HNL Istok)  83      0   0.016040
#
#   Transfer Value     Value
# 0      €3K - €9K    6000.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0             Name  Apps  Mins    Mins/Gm  Height  Weight  Age  \
# 0           0  Josip Mijatović    12   809  67.416667     173      68   20
# 1           1    Duje Ninčević    15  1161  77.400000     172      69   25
# 2           2  Marin Karabatić    15  1350  90.000000     170      62   22
# 3           3     Vicko Ševelj    20  1738  86.900000     192      86   22
# 4           4    Fran Vujnović    15  1384  92.266667     190      77   19
#
#    Av Rat  Distance                           Based  CA  Saves  Dist/Mins  \
# 0    7.14     102.6          Croatia (3. HNL Zapad)  84      0   0.126823
# 1    6.84     150.3            Croatia (3. HNL Jug)  79      0   0.129457
# 2    6.90     172.8            Croatia (3. HNL Jug)  87      0   0.128000
# 3    7.15     101.9  Bosnia & Herzegovina (Liga 12)  95      0   0.058631
# 4    7.23      22.2          Croatia (3. HNL Istok)  83      0   0.016040
#
#   Transfer Value     Value
# 0      €3K - €9K    6000.0
# ...

# %%
# create correct columns


df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#               Name  Apps  Mins    Mins/Gm  Height  Weight  Age  Av Rat  \
# 0  Josip Mijatović    12   809  67.416667     173      68   20    7.14
# 1    Duje Ninčević    15  1161  77.400000     172      69   25    6.84
# 2  Marin Karabatić    15  1350  90.000000     170      62   22    6.90
# 3     Vicko Ševelj    20  1738  86.900000     192      86   22    7.15
# 4    Fran Vujnović    15  1384  92.266667     190      77   19    7.23
#
#    Distance                           Based  CA  Saves  Dist/Mins  \
# 0     102.6          Croatia (3. HNL Zapad)  84      0   0.126823
# 1     150.3            Croatia (3. HNL Jug)  79      0   0.129457
# 2     172.8            Croatia (3. HNL Jug)  87      0   0.128000
# 3     101.9  Bosnia & Herzegovina (Liga 12)  95      0   0.058631
# 4      22.2          Croatia (3. HNL Istok)  83      0   0.016040
#
#   Transfer Value     Value
# 0      €3K - €9K    6000.0
# 1     €0 - €2.5K    1250.0
# 2      €0 - €12K    6000.0
# ...

# %%
df = df.sort_values(by=['Age'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_row', None)

# %%
# drop any duplicate
df['Name'].drop_duplicates().sort_values(ascending=False)
# Out:
# 387                     Žiga Frelih
# 5                    Šimun Mikolčić
# 23                     Đevad Selman
# 1092                  Édouard Mendy
# 1116                   Éder Militão
# 1011                 Çağlar Söyüncü
# 945                Álvaro Fernández
# 984                     Álex Remiro
# 84                      Zé Oliveira
# 422                       Zé Carlos
# 242                  Zvonimir Ziger
# 162                  Zvonimir Blaić
# 362                   Zoran Arsenić
# 961                      Zeki Çelik
# 417                     Zech Medley
# 358                Zdeněk Folprecht
# 1056                  Yves Bissouma
# 398               Youssoupha Ndiaye
# 270                 Youssouf Ndiaye
# 826                   Yordan Osorio
# 718                   Yohann Magnin
# 1093                     Yerry Mina
# 943                           Yeray
# 287               Yassine Delbergue
# 476               Yassine Ben Hamed
# 241               Yannis N'Gakoutou
# ...

# %%
df.head()
# Out:
#                  Name  Apps  Mins    Mins/Gm  Height  Weight  Age  Av Rat  \
# 851       Felipe Melo    38  3057  80.447368     185      82   39    6.83
# 1064      Fernandinho    14  1252  89.428571     179      65   37    7.05
# 1117     Sergio Ramos    11   924  84.000000     184      82   36    7.15
# 304        Luís Rocha    11   990  90.000000     186      83   36    7.26
# 469   Máximo Banguera    40  3617  90.425000     187      98   36    6.59
#
#       Distance                        Based   CA  Saves  Dist/Mins  \
# 851      308.8  Brazil (Brasileiro Série A)  109      0   0.101014
# 1064     145.0              Italy (Serie A)  149      0   0.115815
# 1117     113.9             France (Ligue 1)  156      0   0.123268
# 304      117.8        Portugal (Liga 3 Sul)   91      0   0.118990
# 469       11.2            Ecuador (Serie A)  106      7   0.003096
#
#      Transfer Value       Value
# 851    €95K - €300K    197500.0
# 1064    €2.9M - €6M   4450000.0
# ...

# %%
#Weight correlation
#Age correlation

# %%
# scatter plot with based vs apps

plt.scatter(x=df['Weight'], y=df['Age']) 

plt.title('Weight vs Age')

plt.xlabel('Weight')

plt.ylabel('Age')
plt.show()

# %%
df.head()
# Out:
#                  Name  Apps  Mins    Mins/Gm  Height  Weight  Age  Av Rat  \
# 851       Felipe Melo    38  3057  80.447368     185      82   39    6.83
# 1064      Fernandinho    14  1252  89.428571     179      65   37    7.05
# 1117     Sergio Ramos    11   924  84.000000     184      82   36    7.15
# 304        Luís Rocha    11   990  90.000000     186      83   36    7.26
# 469   Máximo Banguera    40  3617  90.425000     187      98   36    6.59
#
#       Distance                        Based   CA  Saves  Dist/Mins  \
# 851      308.8  Brazil (Brasileiro Série A)  109      0   0.101014
# 1064     145.0              Italy (Serie A)  149      0   0.115815
# 1117     113.9             France (Ligue 1)  156      0   0.123268
# 304      117.8        Portugal (Liga 3 Sul)   91      0   0.118990
# 469       11.2            Ecuador (Serie A)  106      7   0.003096
#
#      Transfer Value       Value
# 851    €95K - €300K    197500.0
# 1064    €2.9M - €6M   4450000.0
# ...

# %%
# plot Weight vs Age using seaborn

sns.regplot(x='Weight', y = 'Age', data=df)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Age'>

# %%
sns.regplot(x='Weight', y = 'Age', data=df , scatter_kws={"color": "red"}, line_kws={"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Age'>

# %%
# lets starts looking at correlation

# %%
df.corr(method='pearson') #pearson, kendall, spearson
# Out:
#                Apps      Mins   Mins/Gm    Height    Weight       Age  \
# Apps       1.000000  0.986803  0.076401 -0.075138 -0.012260  0.049702
# Mins       0.986803  1.000000  0.229158 -0.048203  0.016594  0.054373
# Mins/Gm    0.076401  0.229158  1.000000  0.148438  0.168210  0.037761
# Height    -0.075138 -0.048203  0.148438  1.000000  0.787979  0.065553
# Weight    -0.012260  0.016594  0.168210  0.787979  1.000000  0.136476
# Age        0.049702  0.054373  0.037761  0.065553  0.136476  1.000000
# Av Rat     0.063615  0.081941  0.123844  0.044073  0.072218  0.010340
# Distance   0.485851  0.461473 -0.032258 -0.243994 -0.215500 -0.108464
# CA         0.166157  0.167073  0.038036  0.081956  0.078782 -0.001107
# Saves      0.075241  0.088494  0.097102  0.308489  0.298224  0.075621
# Dist/Mins -0.285602 -0.328280 -0.291244 -0.271143 -0.287658 -0.145353
# Value      0.040932  0.044536  0.032715  0.094848  0.121871 -0.065589
#
# ...

# %%
# high correlation b/w Weight ang Age

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('correlation matrix for Weight and Age') 

plt.xlabel('chart')

plt.ylabel('chart')


plt.show()

# %%
# look at the data

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes


df_numerized.head()
# Out:
#       Name  Apps  Mins    Mins/Gm  Height  Weight  Age  Av Rat  Distance  \
# 851    293    38  3057  80.447368     185      82   39    6.83     308.8
# 1064   296    14  1252  89.428571     179      65   37    7.05     145.0
# 1117   954    11   924  84.000000     184      82   36    7.15     113.9
# 304    589    11   990  90.000000     186      83   36    7.26     117.8
# 469    751    40  3617  90.425000     187      98   36    6.59      11.2
#
#       Based   CA  Saves  Dist/Mins  Transfer Value       Value
# 851       7  109      0   0.101014             543    197500.0
# 1064     49  149      0   0.115815             168   4450000.0
# 1117     25  156      0   0.123268              88  15000000.0
# 304      63   91      0   0.118990             516     17000.0
# 469      21  106      7   0.003096              15     20000.0

# %%
df = pd.read_csv(r'C:\Users\DES\Desktop\variables.csv')
df.head()
# Out:
#    Unnamed: 0             Name  Apps  Mins    Mins/Gm  Height  Weight  Age  \
# 0           0  Josip Mijatović    12   809  67.416667     173      68   20
# 1           1    Duje Ninčević    15  1161  77.400000     172      69   25
# 2           2  Marin Karabatić    15  1350  90.000000     170      62   22
# 3           3     Vicko Ševelj    20  1738  86.900000     192      86   22
# 4           4    Fran Vujnović    15  1384  92.266667     190      77   19
#
#    Av Rat  Distance                           Based  CA  Saves  Dist/Mins  \
# 0    7.14     102.6          Croatia (3. HNL Zapad)  84      0   0.126823
# 1    6.84     150.3            Croatia (3. HNL Jug)  79      0   0.129457
# 2    6.90     172.8            Croatia (3. HNL Jug)  87      0   0.128000
# 3    7.15     101.9  Bosnia & Herzegovina (Liga 12)  95      0   0.058631
# 4    7.23      22.2          Croatia (3. HNL Istok)  83      0   0.016040
#
#   Transfer Value     Value
# 0      €3K - €9K    6000.0
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('correlation matrix for Weight and Age') 

plt.xlabel('chart')

plt.ylabel('chart')


plt.show()

# %%
df_numerized.corr()
# Out:
#                     Name      Apps      Mins   Mins/Gm    Height    Weight  \
# Name            1.000000  0.030628  0.029276 -0.010685 -0.052377 -0.038999
# Apps            0.030628  1.000000  0.986803  0.076401 -0.075138 -0.012260
# Mins            0.029276  0.986803  1.000000  0.229158 -0.048203  0.016594
# Mins/Gm        -0.010685  0.076401  0.229158  1.000000  0.148438  0.168210
# Height         -0.052377 -0.075138 -0.048203  0.148438  1.000000  0.787979
# Weight         -0.038999 -0.012260  0.016594  0.168210  0.787979  1.000000
# Age            -0.017833  0.049702  0.054373  0.037761  0.065553  0.136476
# Av Rat          0.057521  0.063615  0.081941  0.123844  0.044073  0.072218
# Distance       -0.005429  0.485851  0.461473 -0.032258 -0.243994 -0.215500
# Based           0.001795  0.001782  0.004528  0.028200 -0.033309 -0.053775
# CA             -0.009209  0.166157  0.167073  0.038036  0.081956  0.078782
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# Name            Name              1.000000
#                 Apps              0.030628
#                 Mins              0.029276
#                 Mins/Gm          -0.010685
#                 Height           -0.052377
#                 Weight           -0.038999
#                 Age              -0.017833
#                 Av Rat            0.057521
#                 Distance         -0.005429
#                 Based             0.001795
#                 CA               -0.009209
#                 Saves            -0.037893
#                 Dist/Mins        -0.018388
#                 Transfer Value    0.001924
#                 Value            -0.006306
# Apps            Name              0.030628
#                 Apps              1.000000
#                 Mins              0.986803
#                 Mins/Gm           0.076401
#                 Height           -0.075138
#                 Weight           -0.012260
#                 Age               0.049702
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# Saves           Dist/Mins        -0.468726
# Dist/Mins       Saves            -0.468726
#                 Mins             -0.328280
# Mins            Dist/Mins        -0.328280
# Distance        Saves            -0.320093
# Saves           Distance         -0.320093
# Dist/Mins       Mins/Gm          -0.291244
# Mins/Gm         Dist/Mins        -0.291244
# Weight          Dist/Mins        -0.287658
# Dist/Mins       Weight           -0.287658
#                 Apps             -0.285602
# Apps            Dist/Mins        -0.285602
# Dist/Mins       Height           -0.271143
# Height          Dist/Mins        -0.271143
# Distance        Height           -0.243994
# Height          Distance         -0.243994
# Distance        Weight           -0.215500
# Weight          Distance         -0.215500
# Dist/Mins       Age              -0.145353
# Age             Dist/Mins        -0.145353
# Saves           Av Rat           -0.109430
# Av Rat          Saves            -0.109430
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# Value           CA                0.620883
# CA              Value             0.620883
# Dist/Mins       Distance          0.625654
# Distance        Dist/Mins         0.625654
# Height          Weight            0.787979
# Weight          Height            0.787979
# Mins            Apps              0.986803
# Apps            Mins              0.986803
# Name            Name              1.000000
# Av Rat          Av Rat            1.000000
# Dist/Mins       Dist/Mins         1.000000
# Saves           Saves             1.000000
# CA              CA                1.000000
# Based           Based             1.000000
# Distance        Distance          1.000000
# Age             Age               1.000000
# Weight          Weight            1.000000
# Height          Height            1.000000
# Mins/Gm         Mins/Gm           1.000000
# Mins            Mins              1.000000
# Apps            Apps              1.000000
# Transfer Value  Transfer Value    1.000000
# ...
